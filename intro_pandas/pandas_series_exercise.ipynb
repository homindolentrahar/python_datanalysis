# %%
import numpy as np
import pandas as pd

# %%
X = ['A', 'B', 'C']
print(X, type(X))

Y = pd.Series(X)
print(Y, type(Y))
# Out:
# ['A', 'B', 'C'] <class 'list'>
# 0    A
# 1    B
# 2    C
# dtype: object <class 'pandas.core.series.Series'>

# %%
X = pd.Series(['A', 'B', 'C'])
X.name = 'My letters'
X
# Out:
# 0    A
# 1    B
# 2    C
# Name: My letters, dtype: object

# %%
X = pd.Series(['A', 'B', 'C'])
X.values
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
X = pd.Series(['A', 'B', 'C'])
index_names = ['first', 'second', 'third']

X.index = index_names
X
# Out:
# first     A
# second    B
# third     C
# dtype: object

# %%
X = pd.Series(['A', 'B', 'C'], index=['first', 'second', 'third'])

X['first']
# Out:
# 'A'

# %%
x = pd.Series(['A', 'B', 'C'], index=['first', 'second', 'third'])

X['third']
# Out:
# 'C'

# %%
X = pd.Series(['A', 'B', 'C', 'D', 'E'], index=['first', 'second', 'third', 'fourth', 'fifth'])

X[1:-1]
# Out:
# second    B
# third     C
# fourth    D
# dtype: object

# %%
X = pd.Series(['A', 'B', 'C', 'D', 'E'], index=['first', 'second', 'third', 'fourth', 'fifth'])

X[::-1]
# Out:
# fifth     E
# fourth    D
# third     C
# second    B
# first     A
# dtype: object

# %%
X = pd.Series(['A', 'B', 'C', 'D', 'E'], index=['first', 'second', 'third', 'fourth', 'fifth'])

X[[0, -1]]
# Out:
# first    A
# fifth    E
# dtype: object

# %%
X = pd.Series([1, 2, 3, 4, 5], index=['first', 'second', 'third', 'fourth', 'fifth'])

pd.Series(X, dtype=np.float)
# Out:
# C:\Users\homindolentrahar\AppData\Local\Temp\ipykernel_24508\1934747195.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pd.Series(X, dtype=np.float)
# first     1.0
# second    2.0
# third     3.0
# fourth    4.0
# fifth     5.0
# dtype: float64

# %%
X = pd.Series([1, 2, 3, 4, 5], index=['first', 'second', 'third', 'fourth', 'fifth'])

X[::-1]
# Out:
# fifth     5
# fourth    4
# third     3
# second    2
# first     1
# dtype: int64

# %%
X = pd.Series([4, 2, 5, 1, 3], index=['fourth', 'second', 'fifth', 'first', 'third'])

X = X.sort_values()
X
# Out:
# first     1
# second    2
# third     3
# fourth    4
# fifth     5
# dtype: int64

# %%
X = pd.Series([1, 2, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E'])

X[4] = 10
X
# Out:
# A     1
# B     2
# C     3
# D     4
# E    10
# dtype: int64

# %%
X = pd.Series([1, 2, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E'])

X[1:-1] = 0
X
# Out:
# A    1
# B    0
# C    0
# D    0
# E    5
# dtype: int64

# %%
X = pd.Series([1, 2, 3, 4, 5])
X + 5
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
X = pd.Series([-1, 2, 0, -4, 5, 6, 0, 0, -9, 10])

mask = X <= 0
X[mask]
# Out:
# 0   -1
# 2    0
# 3   -4
# 6    0
# 7    0
# 8   -9
# dtype: int64

# %%
X = pd.Series([-1, 2, 0, -4, 5, 6, 0, 0, -9, 10])

mask = X > 5
X[mask]
# Out:
# 5     6
# 9    10
# dtype: int64

# %%
X = pd.Series([-1, 2, 0, -4, 5, 6, 0, 0, -9, 10])

mask = (X == 2) | (X == 10)
X[mask]
# Out:
# 1     2
# 9    10
# dtype: int64

# %%
X = pd.Series([-1, 2, 0, -4, 5, 6, 0, 0, -9, 10])

mask = X > X.mean()
X[mask]
# Out:
# 1     2
# 4     5
# 5     6
# 9    10
# dtype: int64

# %%
X = pd.Series([-1, 2, 0, -4, 5, 6, 0, 0, -9, 10])

X.all()
# Out:
# False

# %%
X = pd.Series([-1, 2, 0, -4, 5, 6, 0, 0, -9, 10])

X.any()
# Out:
# True

# %%
X = pd.Series([3, 5, 6, 7, 2, 3, 4, 9, 4])

X.sum()
# Out:
# 43

# %%
X = pd.Series([3, 5, 6, 7, 2, 3, 4, 9, 4])

X.mean()
# Out:
# 4.777777777777778

# %%
X = pd.Series([1, 2, 0, 4, 5, 6, 0, 0, 9, 10])

X.max()
# Out:
# 10

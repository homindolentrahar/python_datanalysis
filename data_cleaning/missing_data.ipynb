# %%
import numpy as np
import pandas as pd

# %%
falsy_values = (0, False, None, '', [], {})

# %%
any(falsy_values)
# Out:
# False

# %%
np.nan
# Out:
# nan

# %%
3 + np.nan
# Out:
# nan

# %%
a = np.array([1, 2, 3, np.nan, np.nan, 4])

# %%
a.sum()
# Out:
# nan

# %%
a.mean()
# Out:
# nan

# %%
3 + None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 3 + None
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
a = np.array([1, 2, 3, np.nan, None, 4], dtype='float')

# %%
a
# Out:
# array([ 1.,  2.,  3., nan, nan,  4.])

# %%
a = np.array([1, 2, 3, np.nan, np.nan, 4])

# %%
a.mean()
# Out:
# nan

# %%
a.sum()
# Out:
# nan

# %%
np.inf
# Out:
# inf

# %%
3 + np.inf
# Out:
# inf

# %%
np.inf / 3
# Out:
# inf

# %%
np.inf / np.inf
# Out:
# nan

# %%
b = np.array([1, 2, 3, np.inf, np.nan, 4], dtype=np.float)
# Out:
# C:\Users\homindolentrahar\AppData\Local\Temp\ipykernel_23740\2748397628.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   b = np.array([1, 2, 3, np.inf, np.nan, 4], dtype=np.float)

# %%
b.sum()
# Out:
# nan

# %% [markdown]
# ## Checking for nan or inf

# %%
np.isnan(np.nan)
# Out:
# True

# %%
np.isinf(np.inf)
# Out:
# True

# %%
np.isfinite(np.nan), np.isfinite(np.inf)
# Out:
# (False, False)

# %%
np.isnan(np.array([1, 2, 3, np.nan, np.inf, 4]))
# Out:
# array([False, False, False,  True, False, False])

# %%
np.isinf(np.array([1, 2, 3, np.nan, np.inf, 4]))
# Out:
# array([False, False, False, False,  True, False])

# %%
np.isfinite(np.array([1, 2, 3, np.nan, np.inf, 4]))
# Out:
# array([ True,  True,  True, False, False,  True])

# %% [markdown]
# ## Filtering

# %%
a = np.array([1, 2, 3, np.nan, np.nan, 4])

# %%
a[~np.isnan(a)]
# Out:
# array([1., 2., 3., 4.])

# %%
a[np.isfinite(a)]
# Out:
# array([1., 2., 3., 4.])

# %%
a[np.isfinite(a)].sum()
# Out:
# 10.0

# %%
a[np.isfinite(a)].mean()
# Out:
# 2.5
